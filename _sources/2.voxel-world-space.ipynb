% %% [markdown]
% # Voxel-space and World-space

% %%
image = spm_data_read('example_image.nii');

% %%
figure;
imagesc(image(:,:,110));
colormap('gray')

% %%
voxel = image(180,180,110)
% Out:
% voxel = 347.0026
